# %% [markdown]
# # Python语言与经济大数据分析

# %% [markdown]
# # 第7_1讲 数据可视化入门:pyecharts

# %% [markdown]
# #郭峰（上海财经大学投资系副教授）
# #Email：guo.feng@mail.sufe.edu.cn
# #2019-01-19
# #本讲主要介绍数据可视化库pyecharts的基本操作

# %%
#pyecharts简介
#Echarts是一个开源的数据可视化JS库，pyecharts是一个生成Echarts图表的python类库。

#安装
#pip install pyecharts

#图类型
'''
Bar（柱状图/条形图）   
Bar3D（3D 柱状图）   
Boxplot（箱形图）   
EffectScatter（带有涟漪特效动画的散点图）   
Funnel（漏斗图）   
Gauge（仪表盘）   
Geo（地理坐标系）   
Graph（关系图）   
HeatMap（热力图）   
Kline（K线图）   
Line（折线/面积图）   
Line3D（3D 折线图）   
Liquid（水球图）   
Map（地图）   
Parallel（平行坐标系）   
Pie（饼图）   
Polar（极坐标系）   
Radar（雷达图）   
Sankey（桑基图）   
Scatter（散点图）   
Scatter3D（3D 散点图）   
ThemeRiver（主题河流图）   
WordCloud（词云图）
'''

#公共属性
#1.标题栏的属性：一般在实例化（初始化）类型时给与，如bar = Bar（“大标题”，“副标题”，···各种属性···）
#       title_color = “颜色”：标题颜色，可以是‘red’或者‘#0000’
#        title_pos = ‘位置’：标题位置，如‘center’，‘left’···
#        width = 1200：图表的宽
#        height = 800：图表的高
#        background_color = "颜色"：图表的背景色

#标签栏属性
#bar.add（“标签”，x，values，···属性···）
#        'mark_'类，通个'mark_'显示，如 mark_point['max', 'min', 'average']:标出最大最小和平均值的点，
#                mark_point_textcolor,mark_line_symbolsize·····
#        'legend_'类，如legend_pos=‘left’：标签的位置
#         'is_'类，如is_label_show=True：显示每个点的值，is_datazoom_show=True：实现移动控制x轴的数量
#                is_convert = True：x，y轴是否调换

# %%
#柱状图
from pyecharts import Bar
path='D:/python/郭峰Python讲义/数据与结果/'
bar = Bar("我的第一个图表", "这里是副标题")
bar.add("服装", ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"], [5, 20, 36, 10, 75, 90])
bar
#bar.use_theme('dark')   #背景颜色,都有什么呢？
#bar.render(path+"pyecharts_example.html")    # 生成本地 HTML 文件
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ad4f844e230e48a99dbfb54659485b62" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ad4f844e230e48a99dbfb54659485b62 = echarts.init(document.getElementById('ad4f844e230e48a99dbfb54659485b62'), 'light', {renderer: 'canvas'});
#
# var option_ad4f844e230e48a99dbfb54659485b62 = {
#     "title": [
#         {
#             "text": "\u6211\u7684\u7b2c\u4e00\u4e2a\u56fe\u8868",
#             "subtext": "\u8fd9\u91cc\u662f\u526f\u6807\u9898",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
# ...

# %%
from pyecharts import Bar
bar = Bar('基本柱状图','副标题')
bar.add('服装',
        ['衬衫','羊毛衫','雪纺衫','裤子','高跟鞋','袜子'],
        [5,20,36,10,75,90],
        is_more_utils = True    #设置最右侧工具栏
        )
bar.show_config()               #调试输出pyecharts的js配置信息
bar

#add(
#    name,x_axis,y_axis,            #name，#图例名称；x_axis， X轴数据，y_axis， Y轴数据
#    is_stack = False,              #is_stack 数据堆叠，同个类目轴上系列配置相同的stack 值可以堆叠放置
#    bar_category_gap = '20%',**kwargs            #bar_category_gap -> int/str   #类目轴柱状距离，默认20%
#    )
# Out:
# {
#     "title": [
#         {
#             "text": "\u57fa\u672c\u67f1\u72b6\u56fe",
#             "subtext": "\u526f\u6807\u9898",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
# ...

# %%
#堆叠柱状图
from pyecharts import Bar
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("柱状图数据堆叠示例")
bar.add("商家A", attr, v1, is_stack=True)
bar.add("商家B", attr, v2, is_stack=True)
bar.add('商家A',attr,v1,mark_point = ['average'])     #标记点：商家A的平均值
bar.add('商家B',attr,v2,mark_line = ['min','max'])    #标记线：商家B最小/最大值
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3a4274fef43e4f2dbf1e396b6b1a2228" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3a4274fef43e4f2dbf1e396b6b1a2228 = echarts.init(document.getElementById('3a4274fef43e4f2dbf1e396b6b1a2228'), 'light', {renderer: 'canvas'});
#
# var option_3a4274fef43e4f2dbf1e396b6b1a2228 = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6570\u636e\u5806\u53e0\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
#x轴和y轴交换位置
from pyecharts import Bar

attr = ['衬衫','羊毛衫','雪纺衫','裤子','高跟鞋','袜子']
v1 = [5,20,36,10,75,90]
v2 = [10,25,8,60,20,80]
bar = Bar('X 轴与 Y 轴交换')
bar.add('商家A',attr,v1)  
bar.add('商家B',attr,v2,is_convert = True)    # is_convert = True:X 轴与 Y 轴交换
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="84fb78d484354fb49684d1012fe62214" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_84fb78d484354fb49684d1012fe62214 = echarts.init(document.getElementById('84fb78d484354fb49684d1012fe62214'), 'light', {renderer: 'canvas'});
#
# var option_84fb78d484354fb49684d1012fe62214 = {
#     "title": [
#         {
#             "text": "X \u8f74\u4e0e Y \u8f74\u4ea4\u6362",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
#折线图
from pyecharts import Line
from random import randint
from random import seed
x=[x for x in range(365)]
y=[randint(5000,10000) for y in range(365)]
line=Line("Products")
line.add("count", x,y)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="71342ad30f094def9149f2af57699836" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_71342ad30f094def9149f2af57699836 = echarts.init(document.getElementById('71342ad30f094def9149f2af57699836'), 'light', {renderer: 'canvas'});
#
# var option_71342ad30f094def9149f2af57699836 = {
#     "title": [
#         {
#             "text": "Products",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
# ...

# %%
#折线图
from pyecharts import Line

attr = ['衬衫','羊毛衫','雪纺衫','裤子','高跟鞋','袜子']
v1 = [5,20,36,10,75,90]
v2 = [10,25,8,60,20,80]
line = Line('折线示例图')
line.add('商家A',attr,v1,mark_point = ['average'])    
line.add('商家B',attr,v2,is_smooth = True, mark_line = ['max','average'])
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="07353d243c464b7091e9d81aadf67062" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_07353d243c464b7091e9d81aadf67062 = echarts.init(document.getElementById('07353d243c464b7091e9d81aadf67062'), 'light', {renderer: 'canvas'});
#
# var option_07353d243c464b7091e9d81aadf67062 = {
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u793a\u4f8b\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
#定制折线图
from pyecharts import Line

attr = ['衬衫','羊毛衫','雪纺衫','裤子','高跟鞋','袜子']
v1 = [5,20,36,10,75,90]
v2 = [10,25,8,60,20,80]
line = Line('折线示例图')
line.add('商家A',attr,v1,
    mark_point = ['average','max','min'],  #标注点：平均值，最大值，最小值
    mark_point_symbol = 'diamond',         #标注点：钻石形状
    mark_point_textcolor = '#40ff27')      #标注点：标注文本颜色
line.add('商家B',attr,v2,mark_point = ['average','max','min'],
    mark_point_symbol = 'arrow',
    mark_point_symbolsize = 40)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="23b5f69f670e49dd9c1d4e8aae15b962" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_23b5f69f670e49dd9c1d4e8aae15b962 = echarts.init(document.getElementById('23b5f69f670e49dd9c1d4e8aae15b962'), 'light', {renderer: 'canvas'});
#
# var option_23b5f69f670e49dd9c1d4e8aae15b962 = {
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u793a\u4f8b\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
#散点图
from pyecharts import EffectScatter
v1 = [10, 20, 30, 40, 50, 60]
v2 = [25, 20, 15, 10, 60, 33]
es = EffectScatter("带有涟漪特效动画的动态散点图示例")
es.add("effectScatter", v1, v2)
es
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="882fd4f90c3049c2a49c0eb7aab45c68" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_882fd4f90c3049c2a49c0eb7aab45c68 = echarts.init(document.getElementById('882fd4f90c3049c2a49c0eb7aab45c68'), 'light', {renderer: 'canvas'});
#
# var option_882fd4f90c3049c2a49c0eb7aab45c68 = {
#     "title": [
#         {
#             "text": "\u5e26\u6709\u6d9f\u6f2a\u7279\u6548\u52a8\u753b\u7684\u52a8\u6001\u6563\u70b9\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
# ...

# %%
#漏斗图
from pyecharts import Funnel
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
value = [20, 40, 60, 80, 100, 120]
funnel = Funnel("漏斗图示例")
funnel.add("商品", attr, value, is_label_show=True, label_pos="inside", label_text_color="#fff")
funnel
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="536baab666824557a446a185fdca72f0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_536baab666824557a446a185fdca72f0 = echarts.init(document.getElementById('536baab666824557a446a185fdca72f0'), 'light', {renderer: 'canvas'});
#
# var option_536baab666824557a446a185fdca72f0 = {
#     "title": [
#         {
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
#饼图
from pyecharts import Pie
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [11, 12, 13, 10, 10, 10]
pie = Pie("饼图示例")
pie.add("", attr, v1, is_label_show=True)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="415fe06152454de79e5356ad414da608" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_415fe06152454de79e5356ad414da608 = echarts.init(document.getElementById('415fe06152454de79e5356ad414da608'), 'light', {renderer: 'canvas'});
#
# var option_415fe06152454de79e5356ad414da608 = {
#     "title": [
#         {
#             "text": "\u997c\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
#环形饼图
from pyecharts import Pie

attr = ['衬衫','羊毛衫','雪纺衫','裤子','高跟鞋','袜子']
v1 = [5,20,36,10,75,90]
pie = Pie('饼图-环形图示例',title_pos = 'center')
pie.add(
        '',attr,v1,                 #''：图例名（不使用图例）
        radius = [40,75],           #环形内外圆的半径
        is_label_show = True,       #是否显示标签
        label_text_color = None,    #标签颜色
        legend_orient = 'vertical', #图例垂直
        legend_pos = 'left'
        )
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="7942370f00f644eca016c2e67a94b413" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_7942370f00f644eca016c2e67a94b413 = echarts.init(document.getElementById('7942370f00f644eca016c2e67a94b413'), 'light', {renderer: 'canvas'});
#
# var option_7942370f00f644eca016c2e67a94b413 = {
#     "title": [
#         {
#             "text": "\u997c\u56fe-\u73af\u5f62\u56fe\u793a\u4f8b",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
#仪表盘
from pyecharts import Gauge
gauge = Gauge("仪表盘示例")
gauge.add("业务指标", "完成率", 66.66)
gauge.show_config()
gauge.render(path+"pyecharts_example.html")    # 生成本地 HTML 文件
# Out:
# {
#     "title": [
#         {
#             "text": "\u4eea\u8868\u76d8\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2299642,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
# ...

# %%
#面积图) 
from pyecharts import Line

attr = ['衬衫','羊毛衫','雪纺衫','裤子','高跟鞋','袜子']
v1 = [5,20,36,10,75,90]
v2 = [10,25,8,60,20,80]
line = Line('折线面积示例图')
line.add('商家A',attr,v1,is_fill = True,
    line_opacity = 0.2,      #线条不透明度
    area_opacity = 0.4,
    symbol = None)  
line.add('商家B',attr,v2,is_fill = True,
    line_color = '#000',     #黑色
    area_opacity = 0.3,      #填充不透明度
    is_smooth = True)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="33a71c6a3119478c927d9150070d677c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_33a71c6a3119478c927d9150070d677c = echarts.init(document.getElementById('33a71c6a3119478c927d9150070d677c'), 'light', {renderer: 'canvas'});
#
# var option_33a71c6a3119478c927d9150070d677c = {
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u9762\u79ef\u793a\u4f8b\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
#散点图
from pyecharts import Scatter
v1 = [5,20,35,50,65,80]
v2 = [10,20,30,40,50,60]
scatter = Scatter('散点示例图')
scatter.add('A',v1,v2)
scatter.add('B',v1[::-1],v2)    #v1[::-1]代表切片倒序
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c074c68584a44c68810149910f261fb9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c074c68584a44c68810149910f261fb9 = echarts.init(document.getElementById('c074c68584a44c68810149910f261fb9'), 'light', {renderer: 'canvas'});
#
# var option_c074c68584a44c68810149910f261fb9 = {
#     "title": [
#         {
#             "text": "\u6563\u70b9\u793a\u4f8b\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
#散点图：引入第三维，类似气泡图
from pyecharts import Scatter
v1 = [5,20,35,50,65,80]
v2 = [10,20,30,40,50,60]
scatter = Scatter('散点-气泡示例图')
scatter.add('A',v1,v2)
scatter.add('B',v1[::-1],v2,                #v1[::-1]代表切片倒序
            is_visualmap = True,            #显示滑动条
            symbol_size = 30,               #显示图内标点大小
            vasual_range_size = [20,80])    #显示滑动范围
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f5f30e995ebb470a829f4d7213fee6d1" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f5f30e995ebb470a829f4d7213fee6d1 = echarts.init(document.getElementById('f5f30e995ebb470a829f4d7213fee6d1'), 'light', {renderer: 'canvas'});
#
# var option_f5f30e995ebb470a829f4d7213fee6d1 = {
#     "title": [
#         {
#             "text": "\u6563\u70b9-\u6c14\u6ce1\u793a\u4f8b\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
#流向图
from pyecharts import GeoLines, Style
style = Style(
    title_top="#fff",
    title_pos = "center",
    width=1200,
    height=600,
    background_color="#404a59"
)
style_geo = style.add(
    is_label_show=True,
    line_curve=0.2,
    line_opacity=0.6,
    legend_text_color="#eee",
    legend_pos="right",
    geo_effect_symbol="plane",
    geo_effect_symbolsize=15,
    label_color=['#a6c84c', '#ffa022', '#46bee9'],
    label_pos="right",
    label_formatter="{b}",
    label_text_color="#eee",
)
data_guangzhou = [
    ["广州", "上海"],
    ["广州", "北京"],
    ["广州", "南京"],
    ["广州", "重庆"],
    ["广州", "兰州"],
    ["广州", "杭州"]
]
geolines = GeoLines("GeoLines 示例", **style.init_style)
geolines.add("从广州出发", data_guangzhou, **style_geo)
geolines.render()

# %%
#关系图
from pyecharts import Graph
import pandas as pd
path='D:/python/郭峰Python讲义/数据与结果/'
f = open(path+"actors.csv",encoding='gbk')
df1= pd.read_csv(f,header=0,sep=',')

s2=df1['actor1']
s3=df1['actor2']
s4=pd.concat([s2,s3],axis=0).drop_duplicates()
nodes=[]
for i in s4:
    x={"name":i}
    nodes.append(x)
links=[]    
for i in df1.index:
    links.append({"source":df1.loc[i,'actor1'], 'target':df1.loc[i,'actor2']})
graph = Graph("演员关系图", width=600, height=600)
graph.add("", nodes, links, is_label_show=True, label_pos="right",
          graph_repulsion=100, is_legend_show=False,
          line_curve=0.3, label_text_color=None)
graph.render()

# %%
#非常非常详细的pyecharts学习资料：
#http://pyecharts.org/#/zh-cn/charts_base
